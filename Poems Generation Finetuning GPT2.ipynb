# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import pandas as pd
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import numpy as np
import random
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import GPT2Tokenizer, GPT2LMHeadModel, AdamW, get_linear_schedule_with_warmup
from tqdm import tqdm, trange
import torch.nn.functional as F
import csv
import nltk
import os

# %% [markdown]
# ### Loading Data

# %%
topics=os.listdir('topics/')

# %%
poems=pd.DataFrame(columns=['title','content','topic'])

# %%
poems
# Out:
# Empty DataFrame
# Columns: [title, content, topic]
# Index: []

# %%
for topic in topics:
    path='topics/'+topic
    
    for f in os.listdir(path):
        file_path=path+'/'+f
        with open(file_path, 'r') as file:
            text = file.read()
        
        df=pd.DataFrame([[f,text,topic]], columns=['title','content','topic'])
        
        poems=pd.concat([poems,df],ignore_index=True)
    
        #print(os.listdir(path))

# %%
poems
# Out:
#                                                    title  \
# 0      ButterflyPoemsVersesOnAButterflyPoembyJosephWa...
# 1      ButterflyPoemsChristmasButterflyPoembyMichaelS...
# 2      ButterflyPoemsBleedingButterflyPoembyButterfli...
# 3      ButterflyPoemsButterflyPoembyFrankLisaIndiRaFr...
# 4      ButterflyPoemsButterflyEffectPoembyHarunAlNasi...
# ...                                                  ...
# 14330         AngerPoemsAngerPoembyVidyadharDurgekar.txt
# 14331    AngerPoemsTheAngerInMePoembyJonathanPendley.txt
# 14332      AngerPoemsAMothersAngerPoembywardhajawdat.txt
# 14333                   AngerPoemsAngerPoembyScarlet.txt
# 14334             AngerPoemsAngerPoembyyeslinsalazar.txt
#
#                                                  content      topic
# 0      Fair Child of Sun and Summer! we behold\nWith ...  butterfly
# 1      Perhaps it had arrived undercover\nbetween the...  butterfly
# 2      I'm a bleeding butterfly.\nMy wings are made o...  butterfly
# 3      Feel like a butterfly; mostly\nhalf finished\n...  butterfly
# 4      Butterfly Effect\nMy very birth sent forth a t...  butterfly
# ...                                                  ...        ...
# 14330  Searing reason and rationale,\nWith the seethi...      anger
# 14331  This ill temper I have is making me mad\nI blo...      anger
# 14332  you....!\nissue ofmine\nborne with love,\nbirt...      anger
# 14333  it boils within\nslowly poisoning  all that it...      anger
# 14334  'ANGER IS WHEN YOU FEEL LIKE YOU WANT O PUNCH ...      anger
#
# [14335 rows x 3 columns]

# %% [markdown]
# ### Creating a Test Set in order to compare generated text with the original

# %%
#Drop the poems with long text (because having more than 1024 tokens, does not work)
poems = poems[poems['content'].apply(lambda x: len(x.split(' ')) < 250)]

# %%
test_set = poems.sample(n = 20)
poems = poems.loc[~poems.index.isin(test_set.index)]

# %%
#Reset the indexes
test_set = test_set.reset_index()
poems = poems.reset_index()

# %%
#For the test set only, we are going to keep last 10 words in a new column, then remove them from original column
test_set['True_end_content'] = test_set['content'].str.split().str[-10:].apply(' '.join)
test_set['content'] = test_set['content'].str.split().str[:-10].apply(' '.join)

# %%
test_set
# Out:
#     index                                              title  \
# 0     173              PoemPoemsInAPoemPoembyRobertFrost.txt
# 1   10901  GreenPoemsTheGardenerLxxxivOverTheGreenPoembyR...
# 2   14028  MurderPoemsmurderPoemASoulStealerPoembyAceOfBl...
# 3    1510  AngelPoemsStPeterAndTheAngelPoembyDeniseLevert...
# 4    5589         TeacherPoemsMyTeacherPoembyRUPPOKHAREL.txt
# 5    9724  DeathPoemsDonTFearDeathPoembyAleksandrAleksand...
# 6    2193          RainPoemsAprilRainPoembyMathildeBlind.txt
# 7    3476  SleepPoemsWhileTheFatesSleepPoembyLucyMaudMont...
# 8    7785  SympathyPoemsSympathyСочувствиеPoembyAnnaFokin...
# 9    6907  NaturePoemsOhHowSilentIsTheNaturePoembyNikolai...
# 10   6564                    LustPoemsLustPoembyCPSharma.txt
# 11   4945  MotherPoemsThoughtsOfAMotherPoembyJasbirChatte...
# 12    685  CulturePoemsFromTuscanCultureRispettoPoetryPoe...
# 13  12087  DreamPoemsTheDreamIDaredNotDreamPoembyDavidZve...
# 14  13334  GreedPoemsGreedLikeNeverBeforePoembyLawrenceSP...
# 15  11998       GodPoemsKnowGodTrustGodPoembyCeceliaWeir.txt
# 16  11587  BirthPoems0009BeforeBirthThoseWhoWillLeanOverM...
# 17  12116       DreamPoemsSoldiersDreamPoembyWilfredOwen.txt
# 18     80  ButterflyPoemsYouPadlockAButterflyPoembynimald...
# 19  11464  GraduationPoemsAGraduationDayMessagePoembyJose...
#
#                                               content       topic  \
# 0   The sentencing goes blithely on its way And ta...        poem
# 1   Over the green and yellow rice-fields sweep th...       green
# 2   It comes upon me, time and time again. It's th...      murder
# 3   Delivered out of raw continual pain, smell of ...       angel
# 4   Same smiling face of his Same eyes falling on ...     teacher
# 5   Don't fear death in earthly travels. Don't fea...       death
# 6   The April rain, the April rain, Comes slanting...        rain
# 7   Come, let us to the sunways of the west, Haste...       sleep
# 8   Не падай духом никогда, Пока звезда в ночи сия...    sympathy
# 9   Oh, how silent is the nature, It only looks an...      nature
# 10  When on Vedas I concentrate, Human passions co...        lust
# 11  My daughter would turn 10 next month… I find i...      mother
# 12  Tuscan folk verses were such emotional Inspire...     culture
# 13  I've lost the joy that used to meet your smile...       dream
# 14  Like never before. Ever before. Just to feed t...       greed
# 15  Know God Trust God. When you pray And it seems...         god
# 16  Comfortable, oh yes comfortable but how to exp...       birth
# 17  I dreamed kind Jesus fouled the big-gun gears;...       dream
# 18  Hey my Girlie! the nursery teacher you taught ...   butterfly
# 19  May Graduation Day fill your heart With feelin...  graduation
#
#                                      True_end_content
# 0   takes the stroke and time In having its undevi...
# 1   flood. Brothers, let us squander our morning i...
# 2     you a serial killer. I call you a soul stealer.
# 3   the next door, the next terrors of freedom and...
# 4   to remember- salute his stature; The teacher's...
# 5   you are not condemned to slow And everlasting ...
# 6   The rain-clouds flash with April mirth, Like L...
# 7   as lovers danced of yore­ The fates will waken...
# 8   Хоть долог тяжкий путь смирения, Но сердце жиз...
# 9   dazzling comets To a point, that is not in sight.
# 10  vicious or girdle girth, Thus I wander birth t...
# 11  my daughter As beautiful as the flowers I was ...
# 12  and various occasions. Copyright © Muzahidul R...
# 13  blinded thus, I dare not let love go. -August ...
# 14  weep. Like never before. To not end. Like neve...
# 15    aptitude To even guess What He will do for you.
# 16         remember, to be born so wish me luck of it
# 17  Michael; And when I woke he'd seen to our repa...
# 18  love And how to love politely not smoothly as ...
# 19  of Graduation Day Come into your life to forev...

# %%
class PoemText(Dataset):
    def __init__(self, control_code, truncate=False, gpt2_type="gpt2", max_length=1024):

        self.tokenizer = GPT2Tokenizer.from_pretrained(gpt2_type)
        self.text = []

        for row in poems['content']:
          self.text.append(torch.tensor(
                self.tokenizer.encode(f"<|{control_code}|>{row[:max_length]}<|endoftext|>")
            ))
        if truncate:
            self.text = self.text[:20000]
        self.text_count = len(self.text)

    def __len__(self):
        return self.text_count

    def __getitem__(self, item):
        return self.text[item]

# %%
dataset = PoemText(poems['content'], truncate=True, gpt2_type="gpt2")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1110 > 1024). Running this sequence through the model will result in indexing errors

# %% [markdown]
# ### Training the model

# %%
#Get the tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# %%
model = GPT2LMHeadModel.from_pretrained('gpt2')

# %%
#Accumulated batch size (since GPT2 is so big)
def pack_tensor(new_tensor, packed_tensor, max_seq_len):
    if packed_tensor is None:
        return new_tensor, True, None
    if new_tensor.size()[1] + packed_tensor.size()[1] > max_seq_len:
        return packed_tensor, False, new_tensor
    else:
        packed_tensor = torch.cat([new_tensor, packed_tensor[:, 1:]], dim=1)
        return packed_tensor, True, None

# %%
def train(
    dataset, model, tokenizer,
    batch_size=16, epochs=5, lr=2e-5,
    max_seq_len=400, warmup_steps=200,
    gpt2_type="gpt2", output_dir=".", output_prefix="wreckgar",
    test_mode=False,save_model_on_epoch=False,
):
    acc_steps = 100
    device=torch.device("cuda")
    model = model.cuda()
    model.train()

    optimizer = AdamW(model.parameters(), lr=lr)
    scheduler = get_linear_schedule_with_warmup(
        optimizer, num_warmup_steps=warmup_steps, num_training_steps=-1
    )

    train_dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
    loss=0
    accumulating_batch_count = 0
    input_tensor = None

    for epoch in range(epochs):

        print(f"Training epoch {epoch}")
        print(loss)
        for idx, entry in tqdm(enumerate(train_dataloader)):
            (input_tensor, carry_on, remainder) = pack_tensor(entry, input_tensor, 768)

            if carry_on and idx != len(train_dataloader) - 1:
                continue

            input_tensor = input_tensor.to(device)
            outputs = model(input_tensor, labels=input_tensor)
            loss = outputs[0]
            loss.backward()

            if (accumulating_batch_count % batch_size) == 0:
                optimizer.step()
                scheduler.step()
                optimizer.zero_grad()
                model.zero_grad()

            accumulating_batch_count += 1
            input_tensor = None
        if save_model_on_epoch:
            torch.save(
                model.state_dict(),
                os.path.join(output_dir, f"{output_prefix}-{epoch}.pt"),
            )
    return model
